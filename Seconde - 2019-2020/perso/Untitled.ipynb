# %%
MDP1=42910
a=str(input("Bonjour, quel est votre nom ? "))


b=int(input("Veuillez entrer votre mot de passe"))
if MDP1!=b:
    print("ALERTE!!!\nINTRUSION!")
else :
    print("Bienvenu {} dans la base de donnée commune à la CIA & a la DGSI".format(a))
# Out:
# Bienvenu thibaut dans la base de donnée commune à la CIA & a la DGSI
