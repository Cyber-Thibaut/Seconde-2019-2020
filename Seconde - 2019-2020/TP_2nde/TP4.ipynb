# %% [markdown]
# # TP4 -  Premiers pas sur ÉduPython
# ##### CELLIER Thibaut - 2°2

# %% [markdown]
# # I - Exercice 1 :
#
# a) Après avoir tapé les lignes ci-dessus, quelles sont les valeurs de a et b ? (Rappel : un des onglets s’appelle explorateur de variables...) (second rappel : soyez feignants, utilisez le copier-coller)

# %%
a=4
b=6
a=a-1
a
# Out:
# 3

# %%
b
# Out:
# 6

# %%
print("hello World!!")
# Out:
# hello World!!

# %% [markdown]
# # 2) L'Éditeur

# %%
print("bonjour!")
# Out:
# bonjour!

# %%
x=42

# %%
print(x)
# Out:
# 42

# %% [markdown]
# # III. Expressions et types simples
#
# # Exercice 3 :
# Prévoir le résultat de 8.5 / 2.5 , de int(8.5) / int(2.5) et de int(8.5 / 2.5) . Vérifier.

# %%
8.5/2.5
# Out:
# 3.4

# %%
int(8.5)/int(2.5)
# Out:
# 4.0

# %%
int(8.5/2.5)
# Out:
# 3

# %% [markdown]
# # Exercice 4 :
# Que renvoie float(7//2)?

# %% [markdown]
# # Exercices d'entrainement :
# ## Exercice 1 :
#
# Voici un algorithme écrit en langage naturel :
# - Affecter à A la valeur 3
# - Affecter à B la valeur `5 x A`
# - Affecter à C la valeur $B^2$
# - Afficher C
#
#
# Ce même algorithme peut se traduire en langage de programmation Python :

# %%
A=3
B=5*A
C=B**2
print('C =',C)
# Out:
# C = 225

# %% [markdown]
# J'obtient 225.

# %%
A=4
B=5*A
C=B**2
print('C =',C)
# Out:
# C = 400

# %% [markdown]
# J'obtient 400 avec a=4

# %%
a=1
b=5*a
c=b**2
print('c =',c)
# Out:
# c = 25

# %% [markdown]
# # Exercice 2 :

# %% [markdown]
# | Algorithme 1                 | Algorithme 2                 | Algorithme 3               |
# |------------------------------|------------------------------|----------------------------|
# | Affecter à A la valeur 8     | Affecter à M la valeur 3     | Affecter à A la valeur -1  |
# | Affecter à B la valeur 9 x A | Affecter à N la valeur 5     | Affecter à B la valeur 7   |
# | Affecter à C la valeur A + B | Affecter à A la valeur M x N | Affecter à P la valeur $B^A$ |
# | Affecter à D la valeur B – C | Affecter à B la valeur M + N | Affecter à Q la valeur $P^A$ |
# | Afficher D                   | Affecter à C la valeur A/B   | Afficher P                 |
# |                              | Afficher C                   | Afficher Q                 |

# %%
#Algorythme 1 :
print ("Algorythme 1 :")
a=8
b=9*4
c=a+b
d=b-c
print('D =',d)
# Out:
# Algorythme 1 :
# D = -8

# %%
#Algorythme 2 :
print ("Algorythme 2 :")
m=3
n=5
a=m*n
b=m+n
c=a/b
print('C =',c)
# Out:
# Algorythme 2 :
# C = 1.875

# %%
#Algorythme 3 :
print ("Algorythme 3 :")
a=-1
b=7
p=b**a
q=p**a
print('P = ',p)
print('Q = ',q)
# Out:
# Algorythme 3 :
# P =  0.14285714285714285
# Q =  7.0
